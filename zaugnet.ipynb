# %% [markdown]
# Import library

# %%
# Mount your Google Drive
from google.colab import drive 
drive.mount('/content/gdrive')

# %% [markdown]
# Install ZAugNet network and dependencies

# %%
import os 
# !git clone ''

# %pip install -r requirements.txt

# %% [markdown]
# How to preapre your data

# %%
# Put your data in /content/gdrive

# %% [markdown]
# Trainining the model the Model

# %% [markdown]
# Predictiction
